# %% [markdown]
# Exercises

# %% [markdown]
# Starting 12/18/2025

# %%
count = 1

def doThis():
  global count

  for i in range(1, 5, 10):
      count += 10

doThis()
print(count)
# Out:
# 11

# %% [markdown]
# Python Quiz 12/18/25

# %%
# @python___developers

def add(n1=5, n2):
  return(n1+n2)
print(add(10,20))
# Out:
#   File "/tmp/ipython-input-2647506175.py", line 3
#     def add(n1=5, n2):
#                   ^
# SyntaxError: parameter without a default follows parameter with a default

# %% [markdown]
# Error as expected!

# %%
# Corrected Cell

def add(n1=5, n2=7):
  return(n1+n2)
print(add(10,20))
# Out:
# 30

# %%
# 12/20/25 Python Developer

x = 5
while x > 2:
  x -= 2
print(x)
# Out:
# 1
